# %% [markdown]
# <a href="https://colab.research.google.com/github/Brigite16/InterrupcionesSI/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Conectar google colab a Drive
from google.colab import drive
drive.mount('/MyDrive/')
# Out:
# Mounted at /MyDrive/

# %%
#Cargado de datos
import csv
import pandas as pd
import numpy as np
import io
from sklearn.pipeline import Pipeline
from sklearn import preprocessing
from sklearn.base import TransformerMixin
from sklearn.preprocessing import RobustScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
#Cargar datos de Interrupciones
IN_TER = pd.read_csv('/MyDrive/MyDrive/InterrupcionesSI.csv', encoding='utf8', delimiter=',')

# %%
IN_TER.head(100)
# Out:
#                       IDINTERRUPCION          EPS       SEDE TIPOINTERRUPCION  \
# 0   a7a3066294a4e58a4938726a468e70e5     SEDAPAL         ATE       IMPREVISTA
# 1   ae2dc7c7ffca19b65736d398cd635af6     SEDAPAL       COMAS       PROGRAMADA
# 2   d170b375fa131f62a127f17802f3f689    SEDACUSCO  SEDACUSCO       IMPREVISTA
# 3   6e6080d769099128949a78468298da9c     SEDAPAL         SJL       IMPREVISTA
# 4   2509295a47746f87336e8bcc87ce539e      SEDALIB   TRUJILLO       IMPREVISTA
# ..                               ...          ...        ...              ...
# 95  f50056918d0d2c9c83f8434ce9292d8d     SEDAPAL       BRENA       PROGRAMADA
# 96  4edcd00552b50bdede4af08fcffa4492  AGUA TUMBES     TUMBES       IMPREVISTA
# 97  a46b947c452160fed8f3fcaf489511c9     SEDAPAL   SURQUILLO       IMPREVISTA
# 98  2201e84a837d373af087da15f3201c83  AGUA TUMBES     TUMBES       IMPREVISTA
# 99  35b0d6d55f9b8c69964a3a9b7ca9bb89     SEDAPAL         VES       PROGRAMADA
#
# ...

# %%
for col in IN_TER.columns:
  print(col)
# Out:
# IDINTERRUPCION
# EPS
# SEDE
# TIPOINTERRUPCION
# TIPOSERVICIO
# MOTIVOINTERRUPCION
# FECHAINICIO
# HORAINICIO
# FECHAFIN
# HORAFIN
# DEPARTAMENTO
# PROVINCIA
# DISTRITO
# NUMCONEXDOM
# UNIDADESUSO
# NUMCAMIONESPUNTOS
